# %% [markdown]
# # Intro & info

# %% [markdown]
# The mutational status of the IDH1 gene is a prognostic factor for gliomas, including glioblastomas (GBMs).
#
# In this notebook, we will use radiomic features exctracted from MRI to classify glioblastomas as IDH1 wild-type (**IDH wt**) or mutant (**IDH mut**).
#
#
# We will simulate a full pipeline, from image selection to model creation, using only free and publicly available resources.
#
# We will use **HD-GLIO-AUTO** to obtain the segmentation of the lesions, **Pyradiomics** to extract the radiomics features, and **scikit-learn** to build our classifier.
#
# While this notebook will not contain enough data to build a meaningful classifier, it should serve as a starting point to develop a fully functional one.
#
# **Note**: for simplicity, we will refer to IDH1 as "IDH" when generating our dataframes.

# %% [markdown]
# #### Acknowledgments
# This notebook was created by Dr. Gian Marco Conte from the **Mayo Clinic Radiology Informatics Lab** https://www.mayo.edu/research/labs/radiology-informatics/overview
#
# with the help of Drs. Andrey Fedorov and Yashbir Singh.

# %% [markdown]
# # Before we start
# This notebook is optimized to work on the **GCP platform**. (For the Colab version, see LINKTOCOLAB)

# %%
# Specify the project ID that points to your GCP project for billing purposes

#myProjectID="insert your project ID"
myProjectID = "idc-external-005"

# %% [markdown]
# # Import libraries

# %%
! pip install nibabel
# Out:
# Collecting nibabel
#   Downloading nibabel-3.2.1-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14 in /opt/conda/lib/python3.7/site-packages (from nibabel) (1.19.5)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.7/site-packages (from nibabel) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging>=14.3->nibabel) (2.4.7)
# Installing collected packages: nibabel
# Successfully installed nibabel-3.2.1

# %%
import os
import shutil
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)
# %matplotlib inline

# %% [markdown]
# # Packages needed:
#
# - dicomsort (https://dicomsort.com/documentation.html
#
# - HD-GLIO-AUTO (https://github.com/NeuroAI-HD/HD-GLIO-AUTO)
#
# - pydicom (https://pydicom.github.io/)
#
# - pyradiomics (https://pyradiomics.readthedocs.io/en/latest/index.html)

# %% [markdown]
# ### Install pydicom

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-2.2.1-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 5.2 MB/s eta 0:00:01
# Installing collected packages: pydicom
# Successfully installed pydicom-2.2.1

# %% [markdown]
# ### Install dicomsort

# %%
#!git clone https://github.com/pieper/dicomsort.git
# !python dicomsort/dicomsort.py --help
# Out:
# % dicomsort.py --help
# dicomsort [options...] sourceDir targetDir/<patterns>
#
#  where [options...] can be:
#     [-z,--compressTargets] - create a .zip file in the target directory
#     [-d,--deleteSource] - remove source files/directories after sorting
#     [-f,--forceDelete] - remove source without confirmation
#     [-k,--keepGoing] - report but ignore dupicate target files
#     [-v,--verbose] - print diagnostics while processing
#     [-s,--symlink] - create a symlink to dicom files in sourceDir instead of copying them
#     [-t,--test] - run the built in self test (requires internet)
#     [-u,--unsafe] - do not replace unsafe characters with '_' in the path
#     [--help] - print this message
#
#  where sourceDir is directory to be scanned or "" (null string) to read file list from stdin
#
#  where targetDir/<patterns...> is a string defining the output file and directory
#  names based on the dicom tags in the file.
#
# If patterns are not specified, the following default is used:
#
#   %PatientName-%Modality%StudyID-%StudyDescription-%StudyDate/%SeriesNumber_%SeriesDescription-%InstanceNumber.dcm
#
# Example 1:
#
#   dicomsort data sorted/%PatientName/%StudyDate/%SeriesDescription-%InstanceNumber.dcm
#
#   could create a folder structure like:
#
#   sorted/JohnDoe/2013-40-18/FLAIR-2.dcm
#
# Example 2:
#
#   find DicomSourceDir/ | grep "IMA$" | dicomsort -s "" DicomTargetDir
#
#   would scan DicomSourceDir for file pathnames ending in IMA and create an
#   output directory DicomTargetDir. The folder structure will be created using
#   the default pattern with symbolic links to the source dicom data files.

# %% [markdown]
# ### Install HD-GLIO-AUTO

# %%
# !docker pull jenspetersen/hd-glio-auto
# Out:
# Using default tag: latest
# latest: Pulling from jenspetersen/hd-glio-auto
#
# 57c49d0f: Pulling fs layer
# 40447d26: Pulling fs layer
# 2f862619: Pulling fs layer
# 278deddf: Pulling fs layer
# 80049843: Pulling fs layer
# 556b2329: Pulling fs layer
# a0c97a55: Pulling fs layer
# ac14c8e1: Pulling fs layer
# 71a3f797: Pulling fs layer
# 0ca295df: Pulling fs layer
# 3b5df042: Pulling fs layer
# fa9bedc9: Pulling fs layer
# 420927e2: Pulling fs layer
# 0049843: Waiting fs layer
# 6ab5e780: Pulling fs layer
# 56b2329: Waiting fs layer
# bba74816: Pulling fs layer
# 0c97a55: Waiting fs layer
# 1c8b4073: Pulling fs layer
# 9bc51944: Pulling fs layer
# c14c8e1: Waiting fs layer
# 6f28461a: Pulling fs layer
# ad38789a: Pulling fs layer
# 558b3aa0: Pulling fs layer
# Digest: sha256:401b2d8b0d4ab9ed1a2e7438790c81cb7de9e97f9548677cebc7cee0cc7f7b562KDownloading  52.04MB/250.1MBVerifying Checksum Downloading  631.1MB/1.913GBExtracting  1.157GB/1.913GBDownloading  985.2MB/5.543GBDownloading  641.6MB/2.827GBExtracting  4.221GB/7.051GBExtracting  6.607GB/7.051GBExtracting  6.907GB/7.051GBExtracting  6.911GB/7.051GBExtracting  6.929GB/7.051GB
# Status: Downloaded newer image for jenspetersen/hd-glio-auto:latest
# docker.io/jenspetersen/hd-glio-auto:latest

# %% [markdown]
# ### Install pyradiomics

# %%
# !python -m pip install pyradiomics
# !pyradiomics -h
# Out:
# Requirement already satisfied: pyradiomics in /opt/conda/lib/python3.7/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.9.2 in /opt/conda/lib/python3.7/site-packages (from pyradiomics) (1.19.5)
# Requirement already satisfied: PyWavelets>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from pyradiomics) (1.1.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from pyradiomics) (1.15.0)
# Requirement already satisfied: pykwalify>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from pyradiomics) (1.8.0)
# Requirement already satisfied: SimpleITK>=0.9.1 in /opt/conda/lib/python3.7/site-packages (from pyradiomics) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.7/site-packages (from pykwalify>=1.6.0->pyradiomics) (2.8.1)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in /opt/conda/lib/python3.7/site-packages (from pykwalify>=1.6.0->pyradiomics) (0.17.4)
# Requirement already satisfied: docopt>=0.6.2 in /opt/conda/lib/python3.7/site-packages (from pykwalify>=1.6.0->pyradiomics) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /opt/conda/lib/python3.7/site-packages (from ruamel.yaml>=0.16.0->pykwalify>=1.6.0->pyradiomics) (0.2.2)
# usage: pyradiomics image|batch [mask] [Options]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --label N, -l N       (DEPRECATED) Value of label in mask to use for
#                         feature extraction.
#   --version             Print version and exit
#
# Input:
#   Input files and arguments defining the extraction:
#   - image and mask files (single mode) or CSV-file specifying them (batch mode)
#   - Parameter file (.yml/.yaml or .json)
#   - Overrides for customization type 3 ("settings")
#   - Multi-threaded batch processing
#
#   {Image,Batch}FILE     Image file (single mode) or CSV batch file (batch mode)
#   MaskFILE              Mask file identifying the ROI in the Image.
#                         Only required when in single mode, ignored otherwise.
#   --param FILE, -p FILE
#                         Parameter file containing the settings to be used in extraction
#   --setting "SETTING_NAME:VALUE", -s "SETTING_NAME:VALUE"
#                         Additional parameters which will override those in the
#                         parameter file and/or the default settings. Multiple
#                         settings possible. N.B. Only works for customization
#                         type 3 ("setting").
#   --jobs N, -j N        (Batch mode only) Specifies the number of threads to use for
#                         parallel processing. This is applied at the case level;
#                         i.e. 1 thread per case. Actual number of workers used is
#                         min(cases, jobs).
#   --validate            If specified, check if input is valid and check if file locations point to exisiting files
#
# Output:
#   Arguments controlling output redirection and the formatting of calculated results.
#
#   --out FILE, -o FILE   File to append output to.
#   --out-dir OUT_DIR, -od OUT_DIR
#                         Directory to store output. If specified in segment mode, this writes csv output for each processed case. In voxel mode, this directory is used to store the featuremaps. If not specified in voxel mode, the current working directory is used instead.
#   --mode {segment,voxel}, -m {segment,voxel}
#                         Extraction mode for PyRadiomics.
#   --skip-nans           Add this argument to skip returning features that have an
#                         invalid result (NaN)
#   --format {csv,json,txt}, -f {csv,json,txt}
#                         Format for the output.
#                         "txt" (Default): one feature per line in format "case-N_name:value"
#                         "json": Features are written in a JSON format dictionary
#                         (1 dictionary per case, 1 case per line) "{name:value}"
#                         "csv": one row of feature names, followed by one row of
#                         feature values per case.
#   --format-path {absolute,relative,basename}
#                         Controls input image and mask path formatting in the output.
#                         "absolute" (Default): Absolute file paths.
#                         "relative": File paths relative to current working directory.
#                         "basename": Only stores filename.
#   --unix-path, -up      If specified, ensures that all paths in the output
#                         use unix-style path separators ("/").
#
# Logging:
#   Controls the (amount of) logging output to the console and the (optional) log-file.
#
#   --logging-level LEVEL
#                         Set capture level for logging
#   --log-file FILE       File to append logger output to
#   --verbosity [{1,2,3,4,5}], -v [{1,2,3,4,5}]
#                         Regulate output to stderr. By default [3], level
#                         WARNING and up are printed. By specifying this
#                         argument without a value, level INFO [4] is assumed.
#                         A higher value results in more verbose output.

# %% [markdown]
# # Query the TCGA-GBM cohort from the IDC platform using BigQuery
# This cohort contains both pre- and post-surgery studies.
# Since we are interested in the pre-surgery studies, the query will include only the earliest study for each subject.
#
# We will save this information in a pandas dataframe called "tcga_gbm_mri" and refer to it as **imaging dataframe** in the comments.

# %%
# %%bigquery tcga_gbm_mri
#
#
# SELECT
#     P.PatientID,
#     P.StudyDate,
#     P.StudyInstanceUID,
#     P.gcs_url
# FROM
#     `canceridc-data.idc_views.dicom_all` AS P
# WHERE
#     P.collection_id = "tcga_gbm"
#     AND
#     P.Modality = "MR"
#     AND
#     P.StudyDate =
#     (
#         SELECT
#             MIN(C.StudyDate)
#         FROM
#             `canceridc-data.idc_views.dicom_all` AS C
#         WHERE
#             P.PatientID = C.PatientID
#             AND
#             C.collection_id = "tcga_gbm"
#             AND
#             C.Modality = "MR"
#     )
# ORDER BY
# P.PatientID
# Out:
# Query complete after 0.03s: 100%|██████████| 30/30 [00:00<00:00, 13141.42query/s]
# Downloading: 100%|██████████| 249102/249102 [00:01<00:00, 197005.71rows/s]

# %% [markdown]
# #### Note: the gcs_url field contains the URL address for each DICOM file in this collection. We will use this information later in the notebook to download the scans.

# %%
# Let's print the dataframe
tcga_gbm_mri
# Out:
#            PatientID   StudyDate  \
# 0       TCGA-02-0003  1997-06-08
# 1       TCGA-02-0003  1997-06-08
# 2       TCGA-02-0003  1997-06-08
# 3       TCGA-02-0003  1997-06-08
# 4       TCGA-02-0003  1997-06-08
# ...              ...         ...
# 249097  TCGA-76-6664  2002-01-10
# 249098  TCGA-76-6664  2002-01-10
# 249099  TCGA-76-6664  2002-01-10
# 249100  TCGA-76-6664  2002-01-10
# 249101  TCGA-76-6664  2002-01-10
#
#                                                         StudyInstanceUID  \
# 0       1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239
# 1       1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239
# 2       1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239
# 3       1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239
# 4       1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239
# ...                                                                  ...
# 249097  1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790
# 249098  1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790
# 249099  1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790
# 249100  1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790
# 249101  1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790
#
#                                                                                                                                                                                                                                                      gcs_url
# 0       gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239/1.3.6.1.4.1.14519.5.2.1.1706.4001.220079143670418535732331991740/1.3.6.1.4.1.14519.5.2.1.1706.4001.155985359154963790784313803295.dcm#1592632444992521
# 1       gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239/1.3.6.1.4.1.14519.5.2.1.1706.4001.220079143670418535732331991740/1.3.6.1.4.1.14519.5.2.1.1706.4001.292065088978667394712144965715.dcm#1592632445532611
# 2       gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239/1.3.6.1.4.1.14519.5.2.1.1706.4001.251438991621054435135635316288/1.3.6.1.4.1.14519.5.2.1.1706.4001.182340981979083404495600128853.dcm#1592632446876833
# 3       gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239/1.3.6.1.4.1.14519.5.2.1.1706.4001.999878355123004837026028734320/1.3.6.1.4.1.14519.5.2.1.1706.4001.172796066591829052357253758129.dcm#1592632452814857
# 4       gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.145725991542758792340793681239/1.3.6.1.4.1.14519.5.2.1.1706.4001.240348717655601689187872263857/1.3.6.1.4.1.14519.5.2.1.1706.4001.236241315594671202210308608134.dcm#1592632446265443
# ...                                                                                                                                                                                                                                                      ...
# 249097  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790/1.3.6.1.4.1.14519.5.2.1.1188.4001.855165780560370170340861980177/1.3.6.1.4.1.14519.5.2.1.1188.4001.100343171081500912998461772831.dcm#1592632391555989
# 249098  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790/1.3.6.1.4.1.14519.5.2.1.1188.4001.182497160692414636856926373398/1.3.6.1.4.1.14519.5.2.1.1188.4001.180190222289499979980875796199.dcm#1592632376867576
# 249099  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790/1.3.6.1.4.1.14519.5.2.1.1188.4001.182497160692414636856926373398/1.3.6.1.4.1.14519.5.2.1.1188.4001.280823613153772212043085561017.dcm#1592632379595030
# 249100  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790/1.3.6.1.4.1.14519.5.2.1.1188.4001.188264273641316994799482740951/1.3.6.1.4.1.14519.5.2.1.1188.4001.290093504099011504768489851011.dcm#1592632380991315
# 249101  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1188.4001.280508857811965887839758381790/1.3.6.1.4.1.14519.5.2.1.1188.4001.269420253869255008162143572128/1.3.6.1.4.1.14519.5.2.1.1188.4001.164022155820154423184958835407.dcm#1592632382897691
#
# [249102 rows x 4 columns]

# %% [markdown]
# #### Now let's check how many patients and how many exams we have

# %%
num_subjects = len(tcga_gbm_mri["PatientID"].unique())
num_studies = len(tcga_gbm_mri["StudyInstanceUID"].unique())
print(f"Total number of subjects in old approach: {num_subjects}")
print(f"Total number of studies in old approach: {num_studies}")
# Out:
# Total number of subjects in old approach: 259
# Total number of studies in old approach: 284

# %% [markdown]
# Some subjects have multiple studies performed the same day, so we have more studies than subjects.
#
# There is no programmatic way of knowing which study to include, so the only option will be to manually review these cases and select the ones to include (we will do this later in the notebook).

# %% [markdown]
# # Match imaging and genomic information.
#
# We obtained the IDH1 mutational status information from the Genomic Data Commons portal (GDC) https://portal.gdc.cancer.gov/).
#
# You can find the spreadsheet with the genomic information "IDH_mutant_TCGA-GBM.csv" here LINK. The subjects included in this spreadsheet are the ones in which a mutation in the IDH1 gene was detected; hence, they can be included in the "IDH mutant" class.
#
# To date, manually uploading the spreadsheet is the only way to match genomic and imaging data.
#
# For more info see https://datascience.cancer.gov/news-events/blog/cancer-data-aggregator-engine-could-drive-data-aggregation-whole-new-way

# %%
# Load the file with the genomic information
idh_df = pd.read_csv('IDH_mutant_TCGA-GBM.csv')
idh_df
# Out:
#          Case ID   Project  Gender   Age at diagnosis      Days to death  \
# 0   TCGA-12-0818  TCGA-GBM  Female  45 years 230 days   7 years 235 days
# 1   TCGA-12-1088  TCGA-GBM  Female  53 years 309 days  10 years 229 days
# 2   TCGA-16-1460  TCGA-GBM  Female   36 years 59 days                 --
# 3   TCGA-26-1442  TCGA-GBM    Male  43 years 245 days                 --
# 4   TCGA-06-5417  TCGA-GBM  Female  45 years 136 days                 --
# 5   TCGA-14-1456  TCGA-GBM    Male  23 years 310 days                 --
# 6   TCGA-06-6701  TCGA-GBM    Male  60 years 136 days                 --
# 7   TCGA-27-2521  TCGA-GBM    Male  34 years 267 days    1 year 145 days
# 8   TCGA-06-1805  TCGA-GBM  Female  28 years 315 days                 --
# 9   TCGA-06-2570  TCGA-GBM  Female  21 years 266 days                 --
# 10  TCGA-06-6389  TCGA-GBM  Female  49 years 351 days                 --
# 11  TCGA-16-0849  TCGA-GBM    Male  54 years 216 days                 --
# 12  TCGA-06-0221  TCGA-GBM    Male   31 years 11 days    1 year 238 days
# 13  TCGA-19-1788  TCGA-GBM    Male   39 years 57 days           112 days
# 14  TCGA-16-0850  TCGA-GBM  Female  52 years 288 days    1 year 133 days
# 15  TCGA-19-A6J5  TCGA-GBM    Male  40 years 360 days                 --
# 16  TCGA-14-4157  TCGA-GBM    Male  40 years 206 days                 --
# 17  TCGA-14-1458  TCGA-GBM    Male  54 years 176 days           203 days
# 18  TCGA-06-A7TL  TCGA-GBM  Female  30 years 340 days                 --
# 19  TCGA-06-0129  TCGA-GBM    Male  30 years 327 days   2 years 294 days
# 20  TCGA-19-2629  TCGA-GBM    Male  60 years 342 days     2 years 7 days
# 21  TCGA-02-2483  TCGA-GBM    Male  43 years 259 days                 --
# 22  TCGA-14-1821  TCGA-GBM    Male    31 years 7 days    1 year 176 days
# 23  TCGA-12-0827  TCGA-GBM  Female  38 years 214 days    3 years 84 days
# 24  TCGA-32-4208  TCGA-GBM    Male   25 years 82 days                 --
# 25  TCGA-06-0128  TCGA-GBM    Male  66 years 111 days    1 year 326 days
# 26  TCGA-14-0871  TCGA-GBM  Female  74 years 359 days   2 years 150 days
# 27  TCGA-19-1389  TCGA-GBM    Male   51 years 32 days           141 days
#
#    Vital Status Primary Diagnosis
# 0          Dead      Glioblastoma
# 1          Dead      Glioblastoma
# 2         Alive      Glioblastoma
# 3         Alive      Glioblastoma
# 4         Alive      Glioblastoma
# 5         Alive      Glioblastoma
# 6         Alive      Glioblastoma
# 7          Dead      Glioblastoma
# 8         Alive      Glioblastoma
# 9         Alive      Glioblastoma
# 10        Alive      Glioblastoma
# 11        Alive      Glioblastoma
# 12         Dead      Glioblastoma
# 13         Dead      Glioblastoma
# 14         Dead      Glioblastoma
# 15        Alive      Glioblastoma
# 16        Alive      Glioblastoma
# 17         Dead      Glioblastoma
# 18        Alive      Glioblastoma
# 19         Dead      Glioblastoma
# 20         Dead      Glioblastoma
# 21        Alive      Glioblastoma
# 22         Dead      Glioblastoma
# 23         Dead      Glioblastoma
# 24        Alive      Glioblastoma
# 25         Dead      Glioblastoma
# 26         Dead      Glioblastoma
# 27         Dead      Glioblastoma

# %% [markdown]
# The "idh_df" dataframe contains the PatientIDs ('Case ID') of the IDH1 mutant subjects. We will refer to this dataframe as **genomic dataframe**.
#
# Since MRI data is not available for all the subjects of the GDC TCGA-GBM cohort, we will first compare the imaging and genomic dataframes, and then add the IDH1 mutational status when available ("IDH Status").

# %%
# First let's make a copy of the original dataframe
tcga_gbm_mri_idh = tcga_gbm_mri.copy()

# %% [markdown]
# #### Let's check how many subjects of the genomic dataframe are missing from the imaging dataframe.

# %%
# Finds the differences between the IDs columns of the two dataframes
missing_subjects = set(idh_df['Case ID']).difference(set(tcga_gbm_mri_idh['PatientID']))

print(f"A total of {len(missing_subjects)} subjects are missing from the imaging dataframe.")
print("The missing subjects are: "+ str(missing_subjects))
# Out:
# A total of 13 subjects are missing from the imaging dataframe.
# The missing subjects are: {'TCGA-26-1442', 'TCGA-16-0850', 'TCGA-12-1088', 'TCGA-16-0849', 'TCGA-12-0827', 'TCGA-16-1460', 'TCGA-32-4208', 'TCGA-12-0818', 'TCGA-02-2483', 'TCGA-06-1805', 'TCGA-19-A6J5', 'TCGA-06-A7TL', 'TCGA-14-4157'}

# %% [markdown]
# #### Now let's add the IDH status information for the subjects that are present in both dataframes.

# %%
# Add '1' to all images corresponding to an IDH mutant subject and '0' to IDH wt
tcga_gbm_mri_idh['IDH Status'] = tcga_gbm_mri_idh['PatientID'].isin(idh_df['Case ID']).astype(int)

# %%
# List all the images for the IDH mutant subjects
tcga_gbm_mri_idh.loc[tcga_gbm_mri_idh['IDH Status'] == 1]
# Out:
#            PatientID   StudyDate  \
# 38896   TCGA-06-0128  1999-02-18
# 38897   TCGA-06-0128  1999-02-18
# 38898   TCGA-06-0128  1999-02-18
# 38899   TCGA-06-0128  1999-02-18
# 38900   TCGA-06-0128  1999-02-18
# ...              ...         ...
# 232097  TCGA-27-2521  1987-07-09
# 232098  TCGA-27-2521  1987-07-09
# 232099  TCGA-27-2521  1987-07-09
# 232100  TCGA-27-2521  1987-07-09
# 232101  TCGA-27-2521  1987-07-09
#
#                                                         StudyInstanceUID  \
# 38896   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# 38897   1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 38898   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# 38899   1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 38900   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# ...                                                                  ...
# 232097  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232098  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232099  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232100  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232101  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
#
#                                                                                                                                                                                                                                                      gcs_url  \
# 38896   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.244190093169259767085353590019.dcm#1592634419703252
# 38897   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.178150653834502649828798714547.dcm#1592636558729327
# 38898   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.483064039435491061849534492565.dcm#1592634421586492
# 38899   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.298258654588370812068474314303.dcm#1592636564834517
# 38900   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.264367681056898400247780398742.dcm#1592634420068875
# ...                                                                                                                                                                                                                                                      ...
# 232097  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.401946651009042036823821396148.dcm#1592633475299120
# 232098  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.739107246764853439484568258615.dcm#1592633475396448
# 232099  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.273440342697389360017292839411.dcm#1592633474607545
# 232100  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.101799618749764475591299151247.dcm#1592633473557341
# 232101  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.248042997891835245012693682017.dcm#1592633474483982
#
#         IDH Status
# 38896            1
# 38897            1
# 38898            1
# 38899            1
# 38900            1
# ...            ...
# 232097           1
# 232098           1
# 232099           1
# 232100           1
# 232101           1
#
# [19910 rows x 5 columns]

# %%
# Let's visualize only the PatientID and the StudyDate of the IDH mutant class
tcga_gbm_mri_idh.loc[tcga_gbm_mri_idh['IDH Status'] == 1].drop(['gcs_url','StudyInstanceUID'],axis=1).drop_duplicates(['PatientID','StudyDate'])
# Out:
#            PatientID   StudyDate  IDH Status
# 38896   TCGA-06-0128  1999-02-18           1
# 40673   TCGA-06-0129  2000-03-14           1
# 95028   TCGA-06-0221  1998-06-30           1
# 134124  TCGA-06-2570  2007-07-26           1
# 146347  TCGA-06-5417  2008-09-03           1
# 149936  TCGA-06-6389  2009-04-04           1
# 153634  TCGA-06-6701  2009-06-06           1
# 189944  TCGA-14-0871  1991-07-05           1
# 191987  TCGA-14-1456  1999-04-22           1
# 192291  TCGA-14-1458  2000-06-25           1
# 193175  TCGA-14-1821  1998-05-07           1
# 201285  TCGA-19-1389  2002-01-18           1
# 203873  TCGA-19-1788  2002-05-14           1
# 211176  TCGA-19-2629  2003-01-21           1
# 231910  TCGA-27-2521  1987-07-09           1

# %% [markdown]
# # Know your data
#
# Datasets are rarely ready to use to train your models; it is fundamental to perform quality control of the data you are going to use, or you will end up with a useless model.
#
# For example, the cohort we are using contains more than one study per subject, and within each study, there could be repeated scans (usually because of motion artefacts; for example see TCGA-08-0522). Moreover, some of the cases do not have a pre-surgery scan, so they will need to be excluded from the analysis.
#
# It is important to be aware of these details if you are planning to randomly select a subset of patients from a given cohort, as the following example will show.

# %% [markdown]
# # Select random cases

# %% [markdown]
# We will now select 5 subjects for each class:
#
# - IDH Status = 0 (IDH wild type; **IDH wt**)
# - IDH Status = 1 (IDH mutant; **IDH mut**)
#
# We will select only 5 subjects per class to reduce downloading and computing time; in reality, you will need much more data to train a meaningful classifier.
#
# To include more patients, change the value of the "N" variable (remember: in this cohort, we have a total of 15 patients with the IDH mutation).

# %%
N = 5
random_selection = tcga_gbm_mri_idh[['PatientID','IDH Status']].drop_duplicates(['PatientID']).groupby('IDH Status').apply(lambda x:x.sample(N, random_state=33)).reset_index(drop=True)
random_selection
# Out:
#       PatientID  IDH Status
# 0  TCGA-19-5956           0
# 1  TCGA-06-0213           0
# 2  TCGA-08-0350           0
# 3  TCGA-08-0522           0
# 4  TCGA-08-0358           0
# 5  TCGA-06-0128           1
# 6  TCGA-19-2629           1
# 7  TCGA-06-0129           1
# 8  TCGA-14-1821           1
# 9  TCGA-27-2521           1

# %%
m = tcga_gbm_mri_idh.PatientID.isin(random_selection.PatientID) #use the random selection as a "filter" on the main dataframe

final_df = tcga_gbm_mri_idh[m]
final_df
# Out:
#            PatientID   StudyDate  \
# 38896   TCGA-06-0128  1999-02-18
# 38897   TCGA-06-0128  1999-02-18
# 38898   TCGA-06-0128  1999-02-18
# 38899   TCGA-06-0128  1999-02-18
# 38900   TCGA-06-0128  1999-02-18
# ...              ...         ...
# 232097  TCGA-27-2521  1987-07-09
# 232098  TCGA-27-2521  1987-07-09
# 232099  TCGA-27-2521  1987-07-09
# 232100  TCGA-27-2521  1987-07-09
# 232101  TCGA-27-2521  1987-07-09
#
#                                                         StudyInstanceUID  \
# 38896   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# 38897   1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 38898   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# 38899   1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 38900   1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438
# ...                                                                  ...
# 232097  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232098  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232099  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232100  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
# 232101  1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458
#
#                                                                                                                                                                                                                                                      gcs_url  \
# 38896   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.244190093169259767085353590019.dcm#1592634419703252
# 38897   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.178150653834502649828798714547.dcm#1592636558729327
# 38898   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.483064039435491061849534492565.dcm#1592634421586492
# 38899   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.298258654588370812068474314303.dcm#1592636564834517
# 38900   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.264367681056898400247780398742.dcm#1592634420068875
# ...                                                                                                                                                                                                                                                      ...
# 232097  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.401946651009042036823821396148.dcm#1592633475299120
# 232098  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.739107246764853439484568258615.dcm#1592633475396448
# 232099  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.273440342697389360017292839411.dcm#1592633474607545
# 232100  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.101799618749764475591299151247.dcm#1592633473557341
# 232101  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.3775.4001.119470023222804500108388734458/1.3.6.1.4.1.14519.5.2.1.3775.4001.123762435054161578259889405532/1.3.6.1.4.1.14519.5.2.1.3775.4001.248042997891835245012693682017.dcm#1592633474483982
#
#         IDH Status
# 38896            1
# 38897            1
# 38898            1
# 38899            1
# 38900            1
# ...            ...
# 232097           1
# 232098           1
# 232099           1
# 232100           1
# 232101           1
#
# [8404 rows x 5 columns]

# %%
# Get the PatientID of the subjects included
final_df['PatientID'].unique()
# Out:
# array(['TCGA-06-0128', 'TCGA-06-0129', 'TCGA-06-0213', 'TCGA-08-0350',
#        'TCGA-08-0358', 'TCGA-08-0522', 'TCGA-14-1821', 'TCGA-19-2629',
#        'TCGA-19-5956', 'TCGA-27-2521'], dtype=object)

# %% [markdown]
# # Verify the completeness of the studies
#
# In this notebook, we will extract radiomics features from T2- and post-contrast T1-weighted images.
#
# To obtain the segmentations of the lesions, we will use HD-GLIO-AUTO, which needs four  axial sequences as inputs:
# - pre-contrast T1
# - post-contrast T1
# - T2
# - FLAIR
#
# Although we could write a script that programmatically selects the series that we need using DICOM tags, in reality, the heterogeneity of the naming of the sequences makes it hardly feasible. Therefore we suggest to visually inspect your data both for quality control and series selection.
#
# #### To inspect the selected subjects, you can either use the IDC portal (https://portal.imaging.datacommons.cancer.gov/) or retrieve the StudyInstanceUID information from the dataframe we generated and run the following cells:

# %%
def get_idc_viewer_url(StudyInstanceUID):
    return "https://viewer.imaging.datacommons.cancer.gov/viewer/"+StudyInstanceUID

# %%
# Follow the link after printing. Change the StudyInstanceUID as needed.
print(get_idc_viewer_url("1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909"))
# Out:
# https://viewer.imaging.datacommons.cancer.gov/viewer/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909

# %% [markdown]
# ### We found the following issues for the randomly selected subjects:

# %% [markdown]
# For the **IDH wt** subgroup:
# - TCGA-19-5956: does not have all the necessary sequences
# - TCGA-08-0350: does not have all the necessary sequences
# - TCGA-08-0522: does not have all the necessary sequences
# - TCGA-08-0358: the necessary sequences needs to be retrieved from two different studies performed on the same day
#
# For the **IDH mut** subgroup:
# - TCGA-19-2629: does not have all the necessary sequences
# - TCGA-14-1821: only post-surgery scans
# - TCGA-27-2521: does not have all the necessary sequences

# %% [markdown]
# ### As you can see, different issues can be encountered during quality control.
#
# Subjects that do not have all the MRI sequences necessary for the radiomics analysis will need to be excluded.
#
# For the subjects in which the MRI sequences needed to run the segmentation model HD-GLIO-AUTO are missing, we have two options:
#
# - Obtain the segmentations manually or using other models
# - Find a way to substitute the missing scans
#
# Regarding the second option, we could use a generative adversarial network to generate the missing MRI sequences; you can find a paper authored by our group describing this approach here: https://pubs.rsna.org/doi/full/10.1148/radiol.2021203786

# %% [markdown]
# # Select complete MRI studies

# %% [markdown]
# #### After reviewing the cohort, we were able to identify subjects that fullfills the inclusion criteria.
#
# #### You can either use the same subjects we identified, or explore the cohort and find others.

# %%
# Lists of subjects that fulfils the inclusion criteria
IDH_wt = ["TCGA-06-0213", "TCGA-08-0358", "TCGA-02-0033", "TCGA-02-0034", "TCGA-02-0037"]
IDH_mut = ["TCGA-06-0128", "TCGA-06-0129", "TCGA-06-2570", "TCGA-06-5417", "TCGA-06-6389"]
final_list = IDH_mut + IDH_wt

# %%
# Lists of subjects that fulfils the inclusion criteria
IDH_wt = ["TCGA-02-0033"]
IDH_mut = ["TCGA-06-0128"]
final_list = IDH_mut + IDH_wt

# %% [markdown]
# #### Let's update our dataframe with the selected patients

# %%
m = tcga_gbm_mri_idh.PatientID.isin(final_list)

final_df = tcga_gbm_mri_idh[m]
final_df
# Out:
#           PatientID   StudyDate  \
# 2813   TCGA-02-0033  1997-05-26
# 2814   TCGA-02-0033  1997-05-26
# 2815   TCGA-02-0033  1997-05-26
# 2816   TCGA-02-0033  1997-05-26
# 2817   TCGA-02-0033  1997-05-26
# ...             ...         ...
# 40668  TCGA-06-0128  1999-02-18
# 40669  TCGA-06-0128  1999-02-18
# 40670  TCGA-06-0128  1999-02-18
# 40671  TCGA-06-0128  1999-02-18
# 40672  TCGA-06-0128  1999-02-18
#
#                                                        StudyInstanceUID  \
# 2813   1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744
# 2814   1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744
# 2815   1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744
# 2816   1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744
# 2817   1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744
# ...                                                                 ...
# 40668  1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 40669  1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 40670  1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 40671  1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
# 40672  1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909
#
#                                                                                                                                                                                                                                                     gcs_url  \
# 2813   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.323119290918952874626865868030.dcm#1592632595605510
# 2814   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.326535645810693359307312583401.dcm#1592632594735390
# 2815   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.214162620943130559794867273793.dcm#1592632597684401
# 2816   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.272158003279744043259572278361.dcm#1592632595507623
# 2817   gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.189549074915981088674484700653.dcm#1592632594637084
# ...                                                                                                                                                                                                                                                     ...
# 40668  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.145326100447495733962560765218.dcm#1592636558528394
# 40669  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.270271453584776537035782480315/1.3.6.1.4.1.14519.5.2.1.4591.4001.247049290955896150038266040236.dcm#1592636559825286
# 40670  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.146343257946831277020701913154.dcm#1592636558559038
# 40671  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.438274313075488492049664896210.dcm#1592636565813031
# 40672  gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.242931806834566169418817681730.dcm#1592636563996579
#
#        IDH Status
# 2813            0
# 2814            0
# 2815            0
# 2816            0
# 2817            0
# ...           ...
# 40668           1
# 40669           1
# 40670           1
# 40671           1
# 40672           1
#
# [2210 rows x 5 columns]

# %%
final_df['PatientID'].unique()
# Out:
# array(['TCGA-02-0033', 'TCGA-06-0128'], dtype=object)

# %% [markdown]
# # Download and sort imaging data.
#
# #### We will generate two different URL lists based on the IDH status.
#
# For details on downloading data to your notebook, see https://colab.research.google.com/github/ImagingDataCommons/IDC-Examples/blob/master/notebooks/Cohort_download.ipynb

# %%
# List of IDH wild type cases
IDH_wt_url = final_df.loc[final_df['IDH Status'] == 0]
IDH_wt_url = IDH_wt_url.join(IDH_wt_url["gcs_url"].str.split('#', 1, expand=True).rename(columns={0:'gcs_url_no_revision', 1:'gcs_revision'}))
IDH_wt_url["gcs_url_no_revision"].to_csv("gcs_paths_idh_wt.txt", header=False, index=False)

# List of IDH mutant cases
IDH_mut_url = final_df.loc[final_df['IDH Status'] == 1]
IDH_mut_url = IDH_mut_url.join(IDH_mut_url["gcs_url"].str.split('#', 1, expand=True).rename(columns={0:'gcs_url_no_revision', 1:'gcs_revision'}))
IDH_mut_url["gcs_url_no_revision"].to_csv("gcs_paths_idh_mut.txt", header=False, index=False)

# %%
# !head gcs_paths_idh_mut.txt
# Out:
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.244190093169259767085353590019.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.178150653834502649828798714547.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.483064039435491061849534492565.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.298258654588370812068474314303.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.264367681056898400247780398742.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.141969035863480624113562030165.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.619151632501848799260529175220/1.3.6.1.4.1.14519.5.2.1.4591.4001.320654681777692486674411781760.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.179823396467898042263987049873.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.215474562452738191112344016078.dcm
# gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.138320730219650259767107068906.dcm

# %% [markdown]
# ### Download the DICOM files to our virtual machine

# %%
# !mkdir downloaded_cohort
# !cat gcs_paths_idh_wt.txt | gsutil -u $myProjectID -m cp -Ir ./downloaded_cohort
# !cat gcs_paths_idh_mut.txt | gsutil -u $myProjectID -m cp -Ir ./downloaded_cohort
# Out:
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.323119290918952874626865868030.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.326535645810693359307312583401.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.214162620943130559794867273793.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.272158003279744043259572278361.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.189549074915981088674484700653.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.157261943118314967283051532658.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.214385114129508612873196828962.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.254742984561455649682133186671.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.318103808859634478761260959959.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.841237439269259591519299006839/1.3.6.1.4.1.14519.5.2.1.1706.4001.120935777958847286112571348154.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.217292298063144279594494121219.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.752744130807488336981713999769.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.195769974270639706695310844866.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.203758463849183212015829503923.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.199548211285875671863789338717.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.130480680443162542929163829941.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.195303095792044602027235218794.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.202215695868505323427000447335.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.265245905724770922255381414245.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.498866817383758168681238140643.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.865844532115861411143348078057.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.130419968493587009593240767042.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.173543338577875257453648950893.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.113886520908136175049424037220.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.335513741009182533113138297998.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.139284811382493094334745250492.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.296425610061658409885952323978.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.220255258125328930407632314475.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.519516713005864131559037890772.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.550522453163819970939574170790.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.218715107995618178241455448381.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.173944050909663243101733558703.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.264496134189436415186143303920.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.120974260397703797736073937426.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.109801105955772085379283624648.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.286891762249850765196245867441.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.299444672301660643982091517633.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.254776782942309555299382068691.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.103656927833450945713348074367.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.247913453946327636385896636055.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.336939294510504235139158067743.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.729728366581127157895419947479.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.126615013452517099756775332540.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.118530763251489615420760284323.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.534870323131369454094997682301.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.139915951240527637428767402510.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.296643502984292493395648505646.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.979156640521307359193388231072.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.235532742310595606155833018491.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.106063500328043183223182292482.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.225066623702764498749597412736.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.277306750452862451889939402346.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.339486953622358888055851581233.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.207704600111348118876937175432.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.690498472165913803381177957166.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.300750631165653953796447228934.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.303511374175626111681802636971.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.141284421300727948429153660452.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.889033107136686884225046599741.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.754023070685853213356787888770.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.296708798924545656528692095863.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.325883353070740499062387575289.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.100641458030064735433775865274.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.169039008408284176128441170682.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.254598976600099494234315410746.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.252377558021487722926667242593.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.239443396400690161237460616556.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.164010950219635553798802488950.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.395027274059808391720722158394.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.174372396296280031173836331723.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.737528447059734659863364218169.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.135852799890786180752120670928.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.296917224659955213607127699081.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.164266383406128970621642826798.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.242076736467659914184692488133.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.123654593626008209749255353180.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.338245011440079979903848044898.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.841237439269259591519299006839/1.3.6.1.4.1.14519.5.2.1.1706.4001.138720390242100023721457216730.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.502689627290663511396982657080.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.125901971791653486016307265802.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.123152610531731620097969875615.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.329389613199296984441584127757.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.289327336191741230174253217120.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.925565980177291715817096389140.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.230899787305077294029621407157.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.299006510396617153243291898861.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.240122865595877268170041517580.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.237514571158461078100817790725.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.224020630902358655870140924390.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.900816172752916579202115018272.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.262219253994464010490851036432.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.330087077369579124792526775776.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.282726259734832474714746014610.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.492132968167249264395336246193.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.187491184940215356496719675375.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.236874989891898308101730698820.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.129459570695959008439723025698.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.157286643883615213618970759916.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.994135301285041508688876706416.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.294590444291045080445106318606.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.165344550607047028844731413893.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.163114948971143507448326390539.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.189342230408609243190742652005.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.168527842872619431162312676285.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.662616035417274134784487223049.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.307346940184417236937090710205.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.124971520872143717586803066233.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.178118148521070478942753092810.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.268275195347846976712648150462.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.315799703847967351878387709438.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.105582193623664912085623065998.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.141499647801992773333453867193.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.954146670469930738697093741420.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.227869132846797586084930834176.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.265172003113356855846788609523.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.717829559543189755111979471337.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.138905049914438827677141540812.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.117505128445836263325336701848.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.202372125907561416112328976912.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.145095875512693721452990628911.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.311295183624878665673040773059.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.319451629042147769614930117034.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.990344487586306185630821214670.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.182006346543035055500911471591.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.195902122567895126295633010093.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.328472863091911910342814465852.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.221662879077142289156316932609.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.339168098636542682633772488914.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.105412406458352273217876771803.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.321473708812669420901180838383.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.542982664528075142110010968782.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.302887850044117721698167102825.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.245659250924474060935314810100.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.524849043180582512331650725174.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.272769157482097357580754751476.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.116720531873742574604797344459.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.329514783570535095355165937957.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.314924439223798385855214879435.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.128189012126325963972785801839.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.427411998925504805525989093685.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.473704137882193292344107195695.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.245780375386296887261584426796.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.317341465656419998585901608158.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.152066851704926832348325669677.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.301282344311767029836959724821.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.251244997616499782366710656910.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.293487913649765282779807693380.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.279041949389362597374078701729.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.355298559832730097608721267061.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.310994790112968514507530229664.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.247495300360558116408666108321.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.177623422357765844788682978067.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.317881232939422761694439298715.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.194460780666959551475396763269.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.809361140671602999909967648104.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.172151949678545983420924035046.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.165304378424491827454984004927.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.113931703753572825364225228236.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.939832798464015297073474582240.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.325305233908785343093480147113.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.157205850496399947878372924415.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.131876444825808850247148965314.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.148893064725726440743551157478.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.270558460299819946729303376339.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.137011698313647564668467709780.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.616838013162082209242802573120.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.126578347580221355770475147993.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.705836665702300878390023964764.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.177249085138684385758080052007.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.172155033732338311826459124873.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.152729467422740958588089078855.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.208195411445410613466469127678.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.189988898795382525408199044066.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.177497775181745784465939649209.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.177604733276416303515179013031.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.887382777475892082390489209146.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.284890261557565707528503547949.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679/1.3.6.1.4.1.14519.5.2.1.1706.4001.156277983882504222601354845377.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.322914196701313633233237087800.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.327074788946307430939833566547.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.213978764468489333358849832888.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.122286024887546980427439039909.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.650811821851504379898694741450.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.327769072973545653453666563238.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.182062483967460027179412071500.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.105886371373257597995641713499.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444/1.3.6.1.4.1.14519.5.2.1.1706.4001.119615585163816587863056622002.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.334459271180847807492272105664.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.841237439269259591519299006839/1.3.6.1.4.1.14519.5.2.1.1706.4001.268649764549968666822685339016.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.139522317906035493956612343835.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.560673871805800018249436499190.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.101526860222133882291224074954.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465/1.3.6.1.4.1.14519.5.2.1.1706.4001.262721588277983727952097606911.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.164552986865789983711311824255/1.3.6.1.4.1.14519.5.2.1.1706.4001.184353335017450545339509232731.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.101860924898346942661707983843.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.332057345316209711159045922828/1.3.6.1.4.1.14519.5.2.1.1706.4001.712741002570303054370330600949.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.874349474095633498635576824961/1.3.6.1.4.1.14519.5.2.1.1706.4001.323861335562074766952784973475.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836/1.3.6.1.4.1.14519.5.2.1.1706.4001.340017430373442429479620775997.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.250526316070055292979086457976/1.3.6.1.4.1.14519.5.2.1.1706.4001.358068933290163540892798119206.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/1.3.6.1.4.1.14519.5.2.1.1706.4001.105844169858907809389536619529/1.3.6.1.4.1.14519.5.2.1.1706.4001.191118349234964189040153230840.dcm...
# ...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.559843757600057404193059467670.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.878946079999119102183166639101.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.210605600488632094456411105831.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.120673894695124200101185494671/1.3.6.1.4.1.14519.5.2.1.4591.4001.312781420362709309462816918529.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.135398349955998954637039359544.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.260538845404869521674676730818.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.255899572319713374083105110633.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.527797237559393883952449502905.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.153593873402866934893688025530.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.104724608496672151967320626842/1.3.6.1.4.1.14519.5.2.1.4591.4001.307257640912649297215337850192.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.310120857268214634498067949350/1.3.6.1.4.1.14519.5.2.1.4591.4001.263297196850900945251383773359.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.199689671454856670111994442021.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.150652865498956518150923900822.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.178756934604902194692977554558.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.200911509640134617113758070078.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.644854543519292483085175173019.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.177781644092385787191264674395.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.191517267590033779321527438830/1.3.6.1.4.1.14519.5.2.1.4591.4001.153158561901079377870921882781.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.120673894695124200101185494671/1.3.6.1.4.1.14519.5.2.1.4591.4001.198605993012889215678813856353.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.326472807903617193285873791790.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.252791186464921053332704673690.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.574793276512372302574154076700.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.104724608496672151967320626842/1.3.6.1.4.1.14519.5.2.1.4591.4001.438656285581998033653973315818.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.261881553126075086924072404261.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.619151632501848799260529175220/1.3.6.1.4.1.14519.5.2.1.4591.4001.253878437453397165246137643984.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.296396164552086261396732662759/1.3.6.1.4.1.14519.5.2.1.4591.4001.256030210210731445829631234132.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.651359394442711367070939266432/1.3.6.1.4.1.14519.5.2.1.4591.4001.535140686147690882429470626283.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.211079213275989310412302326932.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.224097534733143058264722484663.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.315384727611804910252848505526.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.270271453584776537035782480315/1.3.6.1.4.1.14519.5.2.1.4591.4001.204534633285056229814674183621.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.179457807386381937795816803043.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.120673894695124200101185494671/1.3.6.1.4.1.14519.5.2.1.4591.4001.228496515348887965799458083480.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.310120857268214634498067949350/1.3.6.1.4.1.14519.5.2.1.4591.4001.172833101433701654050020860272.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.967272929197937214207760743579.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.335939258724659959288964376538.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.107378273336174261946695201061.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.412664512119273906448452076173.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.340107441662702329792805988512.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.579347517574735391943029188674.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.974861052207508620502785540030.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.141137950693165319303684436618.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.651359394442711367070939266432/1.3.6.1.4.1.14519.5.2.1.4591.4001.203982577963049593784422829467.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.199964269444027473816813435241.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.120673894695124200101185494671/1.3.6.1.4.1.14519.5.2.1.4591.4001.174309154483547701555959610626.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.296396164552086261396732662759/1.3.6.1.4.1.14519.5.2.1.4591.4001.287678532651805986640165860096.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.270271453584776537035782480315/1.3.6.1.4.1.14519.5.2.1.4591.4001.112743825139613280474537063747.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.270271453584776537035782480315/1.3.6.1.4.1.14519.5.2.1.4591.4001.236913550050241934251041661646.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.120673894695124200101185494671/1.3.6.1.4.1.14519.5.2.1.4591.4001.946132880189347787892102199720.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.270046576172138340894086930414.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.298175460263878565504151246706.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.697735598413555636533908203783/1.3.6.1.4.1.14519.5.2.1.4591.4001.162083958477655074168149287171.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.155987932372490417929540843368/1.3.6.1.4.1.14519.5.2.1.4591.4001.122019625711614845239143230077.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.552551073457689623708844500269.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258287807788406181423435405994/1.3.6.1.4.1.14519.5.2.1.4591.4001.231505764900911846784769587401.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.191517267590033779321527438830/1.3.6.1.4.1.14519.5.2.1.4591.4001.194752755583826556762082454889.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.250924895266759730810444414705.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.148893787493884808730811708843.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.197146947506099366832803736438/1.3.6.1.4.1.14519.5.2.1.4591.4001.393766610979582366190694521912/1.3.6.1.4.1.14519.5.2.1.4591.4001.278336766982983322654769305296.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.138443378746316459793758800677.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.846673774080673647267576452850.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.145326100447495733962560765218.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.270271453584776537035782480315/1.3.6.1.4.1.14519.5.2.1.4591.4001.247049290955896150038266040236.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.258624254650871593065381246886/1.3.6.1.4.1.14519.5.2.1.4591.4001.146343257946831277020701913154.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.242931806834566169418817681730.dcm...
# Copying gs://idc-tcia-tcga-gbm/dicom/1.3.6.1.4.1.14519.5.2.1.4591.4001.796093665645495657978672735909/1.3.6.1.4.1.14519.5.2.1.4591.4001.575709654718829638269159655776/1.3.6.1.4.1.14519.5.2.1.4591.4001.438274313075488492049664896210.dcm...
# | [1.8k/1.8k files][114.8 MiB/114.8 MiB] 100% Done   3.8 MiB/s ETA 00:00:00
# Operation completed over 1.8k objects/114.8 MiB.

# %% [markdown]
# ### Sort the downloaded DICOM files using dicomosort

# %% [markdown]
# The DICOM images will be copied and sorted in the folder "cohort_sorted"

# %%
# !python dicomsort/dicomsort.py -u downloaded_cohort cohort_sorted/%PatientID/%StudyDate/%StudyInstanceUID/%SeriesDescription/%SeriesInstanceUID/%SOPInstanceUID.dcm
# Out:
# 100%|██████████████████████████████████████| 2210/2210 [00:03<00:00, 685.96it/s]
# Files sorted

# %% [markdown]
# # Obtain the segmentations using HD-GLIO-AUTO

# %% [markdown]
# HD-GLIO-AUTO is the result of a joint project between the Department of Neuroradiology at the Heidelberg University Hospital, Germany and the Division of Medical Image Computing at the German Cancer Research Center (DKFZ) Heidelberg, Germany.
#
# For more information see https://github.com/NeuroAI-HD/HD-GLIO-AUTO
#
# As explained earlier, it requires four MRI sequence to obtain the segmentation of the lesions.
#
# HD-GLIO-AUTO can work directly with DICOM files, but requires each folder to follow a precise organization and naming scheme (see gitHub page for more details).
#
# Given the heterogeneity of the studies, we will opt for a manual cleaning and organization of the folders, which consist in deleting unnecessary studies and rename the folders using the following naming scheme:
#
# - T1: for folders containing pre-contrast T1 images
# - CT1: for folders containing post-contrast T1 images
# - T2: for folders containing T2 images
# - FLAIR: for folders containing FLAIR images

# %% [markdown]
# #### Notes from data cleaning:
#
# - TCGA-06-0128: this subject has two identical studies performed the same day, with different StudyInstanceUID but same acquisition time; we can safely get rid of one of the studies.
# - TCGA-06-0128: this subject has two post-contrast T1 series, one of which contains only 4 slices; since it is unclear why this serie was acquired, or what it represents, we can delete it for the purpose of this notebook.
# - TCGA-06-0128: the T2 sequence is a dual echo FSE (http://mriquestions.com/dual-echo-fse.html); will it work with HD-glio?
# - TCGA-06-0129: (one of) the post-contrast T1 serie has no series description tag

# %% [markdown]
# TO DO: provide cleaned examples to avoid the manual cleaning process to the users

# %% [markdown]
# # DEV

# %% [markdown]
# Temporary (ugly) workaround the cleaning process

# %%
os.getcwd()
# Out:
# '/home/jupyter'

# %%
os.chdir('./cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744')

# %%
# temporary workaround the data cleaning process
#os.listdir('./cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744')
os.listdir()
# Out:
# ['SAG T1 POST',
#  'COR T1 POST',
#  'AX FLAIR',
#  '3D WAND T1 WEIGHTED',
#  'Diffusion Weighted',
#  'AX T2 FSE',
#  'LOC',
#  'AX T1',
#  '2D WAND T2 WEIGHTED',
#  'AX T1 POST']

# %%
os.rename('AX T1','T1')
os.rename('AX T1 POST','CT1')
os.rename('AX T2 FSE','T2')
os.rename('AX FLAIR','FLAIR')

# %%
shutil.rmtree('SAG T1 POST')
shutil.rmtree('2D WAND T2 WEIGHTED')
shutil.rmtree('LOC')
shutil.rmtree('Diffusion Weighted')
shutil.rmtree('COR T1 POST')
shutil.rmtree('3D WAND T1 WEIGHTED')

# %%
os.mkdir('segmentation_output')

# %%
os.listdir()
# Out:
# ['segmentation_output', 'T2', 'T1', 'FLAIR', 'CT1']

# %%
os.getcwd()
# Out:
# '/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744'

# %%
# get back to the main directori
os.chdir('/home/jupyter')

# %%
os.getcwd()
# Out:
# '/home/jupyter'

# %% [markdown]
# ### Now let's run a test using HD-GLIO-AUTO

# %% [markdown]
# #### Here is the general command to run HD-GLIO-AUTO
# docker run --mount type=bind,source=YOUR_INPUT_FOLDER,target=/input --mount type=bind,source=YOUR_OUTPUT_FOLDER,target=/output jenspetersen/hd-glio-auto
#
# We will replace "docker run" with "nvidia-docker run"; for more details see https://github.com/NeuroAI-HD/HD-GLIO-AUTO

# %%
# !nvidia-docker run --mount type=bind,source="/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744",target=/input --mount type=bind,source="/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/segmentation_output",target=/output jenspetersen/hd-glio-auto
# Out:
# 09:30:23 PM: Reading series 1.3.6.1.4.1.14519.5.2.1.1706.4001.103174687731052142735983046836
# 09:30:23 PM: Reading series 1.3.6.1.4.1.14519.5.2.1.1706.4001.287753826073472752590065451465
# 09:30:23 PM: Reading series 1.3.6.1.4.1.14519.5.2.1.1706.4001.261091685370401963952512175444
# 09:30:23 PM: Reading series 1.3.6.1.4.1.14519.5.2.1.1706.4001.116289242878713280880004720679
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=999 : unknown error
# Traceback (most recent call last):
#   File "/usr/local/bin/hd-bet", line 7, in <module>
#     exec(compile(f.read(), __file__, 'exec'))
#   File "/HD-BET/HD_BET/hd-bet", line 119, in <module>
#     run_hd_bet(input_files, output_files, mode, config_file, device, pp, tta, save_mask, overwrite_existing)
#   File "/HD-BET/HD_BET/run.py", line 63, in run_hd_bet
#     net.cuda(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 458, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 354, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 376, in _apply
#     param_applied = fn(param)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 458, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 190, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (999) : unknown error at /pytorch/aten/src/THC/THCGeneral.cpp:47
# Using contrast T1 as reference
# Traceback (most recent call last):
#   File "scripts/run.py", line 505, in <module>
#     not args.no_permissions
#   File "scripts/run.py", line 280, in run
#     output1 = subp.check_output(["hd-bet", "-i", file_, "-device", "0"])
#   File "/usr/lib/python3.6/subprocess.py", line 356, in check_output
#     **kwargs).stdout
#   File "/usr/lib/python3.6/subprocess.py", line 438, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['hd-bet', '-i', '/output/T1_r2s.nii.gz', '-device', '0']' returned non-zero exit status 1.

# %% [markdown]
# #### Check the segmentation (TODO: switch to itkwidgets viewer)

# %%
T2_mri = nib.load('/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/segmentation_output/T2_r2s_bet_reg.nii.gz').get_fdata()
T1Gd_mri = nib.load('/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/segmentation_output/CT1_r2s_bet_reg.nii.gz').get_fdata()
segmentation_mask = nib.load('/home/jupyter/cohort_sorted/TCGA-02-0033/19970526/1.3.6.1.4.1.14519.5.2.1.1706.4001.211135800355624542661804589744/segmentation_output/segmentation.nii.gz').get_fdata()

# %%
# Make zero values in the mask as nan for best visualization
segmentation_mask[segmentation_mask == 0.0] = np.nan

# rotate the image
T2_mri_rot = np.rot90(T2_mri, 1)
T1Gd_mri_rot = np.rot90(T1Gd_mri, 1)
segmentation_mask_rot = np.rot90(segmentation_mask, 1)

# %%
plt.figure(figsize = (10,10))
plt.imshow(T2_mri_rot[:,:,15],cmap="gray")
plt.imshow(segmentation_mask_rot[:,:,15],cmap='bwr',alpha=0.2)

# %%
plt.figure(figsize = (10,10))
plt.imshow(T1Gd_mri_rot[:,:,15],cmap="gray")
plt.imshow(segmentation_mask_rot[:,:,15],cmap='bwr',alpha=0.1)
